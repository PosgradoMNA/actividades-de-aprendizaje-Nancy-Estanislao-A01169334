# %%
path = '/content/drive/MyDrive/datasets/adult.csv'

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv(path)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-10c1b0b75bb4> in <module>
# ----> 1 df = pd.read_csv(path)
#       2 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
## Generate a pivot table showing the number of people for each marital status.

# %%
myTable = pd.pivot_table(df,         
               index = 'marital-status',
               aggfunc = ['count'], 
               values = ['fnlwgt'],
               margins = True,
)
myTable
# Out:
#                         count
#                        fnlwgt
# marital-status
#  Divorced                4443
#  Married-AF-spouse         23
#  Married-civ-spouse     14976
#  Married-spouse-absent    418
#  Never-married          10683
#  Separated               1025
#  Widowed                  993
#  test_category_female       1
#  test_category_male         2
# All                     32564

# %%
#Add a column showing the percentage of people for each marital status.

# %%
x = len(df)

# %%
x
# Out:
# 32564

# %%
myTable
# Out:
#                         count
#                        fnlwgt
# marital-status
#  Divorced                4443
#  Married-AF-spouse         23
#  Married-civ-spouse     14976
#  Married-spouse-absent    418
#  Never-married          10683
#  Separated               1025
#  Widowed                  993
#  test_category_female       1
#  test_category_male         2
# All                     32564

# %%
myTable['percentage'] = (myTable['count']/x) * 100

# %%
myTable
# Out:
#                         count  percentage
#                        fnlwgt
# marital-status
#  Divorced                4443   13.643901
#  Married-AF-spouse         23    0.070630
#  Married-civ-spouse     14976   45.989436
#  Married-spouse-absent    418    1.283626
#  Never-married          10683   32.806166
#  Separated               1025    3.147648
#  Widowed                  993    3.049380
#  test_category_female       1    0.003071
#  test_category_male         2    0.006142
# All                     32564  100.000000

# %%
#Group the three types of married people and repeat the steps.
